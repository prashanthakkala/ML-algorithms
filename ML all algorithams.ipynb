# %% [markdown]
# ## Import the data and display the head, shape and description of the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\hp123\\desktop\\iris\\Iris.csv")
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #  Univariate and Bivariate Analysis

# %% [markdown]
# ### This  kde plot  show the Distributions of each Variable.

# %%
sns.kdeplot(data=df,x="SepalLengthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x="SepalWidthCm")
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x="PetalLengthCm")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x="PetalWidthCm")
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %% [markdown]
# ### Heatmap is a data visualization technique, which represents data using different colours in two dimensions. and the different color shows the different values

# %%
sns.heatmap(df.corr(), annot=True, cmap='gist_stern_r' )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Two main functions in seaborn are used to visualize a linear relationship as determined through regression.these are used to find the relation between the poins these are regplot and limplot

# %%
sns.regplot(x='SepalWidthCm',y='PetalWidthCm',data=df)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='PetalWidthCm'>

# %%
sns.lmplot(x="SepalWidthCm", y="PetalWidthCm", hue="Species",
               data=df)

# %%
sns.jointplot(x="SepalWidthCm", y="PetalWidthCm", data=df, kind="reg");

# %% [markdown]
# ## Pairplot uses to get the relation between each and every variable present in Pandas DataFrame and it shows the Distribution of the setosa,versicolor,virginica

# %%
sns.pairplot(df,hue="Species")

# %% [markdown]
# ### Seaborn literally counts the number of observations  in the given variable

# %%
fig=plt.subplots(figsize=(10,5))

sns.countplot(x = df['SepalLengthCm'])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='count'>

# %% [markdown]
# ### A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.
# ### In this scatter plot is tells about the SepalLengthCm,SepalWidthCm with the Speices

# %%
fig=plt.subplots(figsize=(8,5))

sns.scatterplot(x = "SepalLengthCm", y = "SepalWidthCm", data = df, hue = "Species")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
fig=plt.subplots(figsize=(8,5))

sns.scatterplot(x = "PetalLengthCm", y = "PetalWidthCm", data = df, hue = "Species")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# #  Step-3

# %% [markdown]
#   identify the target variable and inputs in the data set in this data set my target variable is species and inputs is "SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm" these are the inputs

# %% [markdown]
# A machine learning task is the type of prediction and it identify the which one is sutable for these michene learning algorithams classification task assigns data to categories

# %% [markdown]
#  In this given data having the mesuring the accuracy of the prediction values accuracy percentage of the traing algorithams and the to identify the  spliting the test and preducting the values  how much prediction level to caluculating

# %% [markdown]
# ##   Split the dataset into Training and Testing (recommended 75:25 split).

# %%
target=df["Species"]
inputs=df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]

# %%
target
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# ## Data Preparation - Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, target, train_size=0.75, random_state=100)

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 136            6.3           3.4            5.6           2.4
# 114            5.8           2.8            5.1           2.4
# 41             4.5           2.3            1.3           0.3
# 90             5.5           2.6            4.4           1.2
# 102            7.1           3.0            5.9           2.1
# ..             ...           ...            ...           ...
# 87             6.3           2.3            4.4           1.3
# 103            6.3           2.9            5.6           1.8
# 67             5.8           2.7            4.1           1.0
# 24             4.8           3.4            1.9           0.2
# 8              4.4           2.9            1.4           0.2
#
# [112 rows x 4 columns]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (112, 4) (112,)
# (38, 4) (38,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
X_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 136            6.3           3.4            5.6           2.4
# 114            5.8           2.8            5.1           2.4
# 41             4.5           2.3            1.3           0.3
# 90             5.5           2.6            4.4           1.2
# 102            7.1           3.0            5.9           2.1

# %%
X_test.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 128            6.4           2.8            5.6           2.1
# 11             4.8           3.4            1.6           0.2
# 118            7.7           2.6            6.9           2.3
# 15             5.7           4.4            1.5           0.4
# 123            6.3           2.7            4.9           1.8

# %%
y_test.shape
# Out:
# (38,)

# %%
y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)

# %% [markdown]
# ### Label encoding on target columns

# %%
cut_encoder = {'Iris-virginica' : 1, 'Iris-setosa': 2, 'Iris-versicolor' : 3}

y_train['Species'] = y_train['Species'].apply(lambda x : cut_encoder[x])

y_train.head()
# Out:
#      Species
# 136        1
# 114        1
# 41         2
# 90         3
# 102        1

# %%
cut_encoder = {'Iris-virginica' : 1, 'Iris-setosa': 2, 'Iris-versicolor' : 3}

y_test['Species'] = y_test['Species'].apply(lambda x : cut_encoder[x])

y_test.head()
# Out:
#      Species
# 128        1
# 11         2
# 118        1
# 15         2
# 123        1

# %% [markdown]
# ##  Standardization  on input columns

# %%
# scaling the numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train = pd.DataFrame(scaler.fit_transform(X_train), 
                      columns = X_train.columns)

X_train.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       0.605209      0.837094       1.060662      1.587319
# 1      -0.007661     -0.601594       0.771343      1.587319
# 2      -1.601121     -1.800502      -1.427476     -1.205032
# 3      -0.375383     -1.081157       0.366298     -0.008311
# 4       1.585800     -0.122032       1.234253      1.188411

# %%
X_test = pd.DataFrame(scaler.transform(X_test),columns = X_test.columns)

X_test.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       0.727782     -0.601594       1.060662      1.188411
# 1      -1.233400      0.837094      -1.253885     -1.338001
# 2       2.321243     -1.081157       1.812889      1.454349
# 3      -0.130235      3.234908      -1.311749     -1.072063
# 4       0.605209     -0.841376       0.655616      0.789504

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (112, 4) (112, 1)
# (38, 4) (38, 1)

# %% [markdown]
# ##  Model Training Phase - Use all the algorithms mentioned below to train separate models:
# - KNN
# - Logistic Regression
# - Decision Trees
# - Random Forest
# - Support Vector Machines

# %% [markdown]
# ## Training

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train, y_train)
# Out:
# C:\Users\hp123\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %% [markdown]
# ##  Predictions

# %%
y_test_pred = classifier.predict(X_test)

# %% [markdown]
# ## Measuring Performance

# %%
from sklearn.metrics import accuracy_score
KNN=accuracy_score(y_test, y_test_pred)

# %%
print(KNN)
# Out:
# 0.9736842105263158

# %%
metrics.plot_confusion_matrix(classifier, X_test, y_test)

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# C:\Users\hp123\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %% [markdown]
# # Prediction

# %%
y_test_pred = classifier.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import accuracy_score
logistic=accuracy_score(y_test, y_test_pred)
print(logistic)
# Out:
# 0.9473684210526315

# %%
metrics.plot_confusion_matrix(classifier, X_test, y_test)

# %% [markdown]
# ##  DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
DT=accuracy_score(y_test, y_test_pred)

# %%
print(DT)
# Out:
# 0.9473684210526315

# %%
metrics.plot_confusion_matrix(classifier, X_test, y_test)

# %% [markdown]
# ##  RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
# Out:
# C:\Users\hp123\AppData\Local\Temp/ipykernel_5832/744122253.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(X_train, y_train)
# RandomForestClassifier()

# %%
y_test_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
RF=accuracy_score(y_test, y_test_pred)

# %%
print(RF)
# Out:
# 0.9473684210526315

# %%
metrics.plot_confusion_matrix(classifier, X_test, y_test)

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.svm import SVC 
classifier = SVC() 
classifier.fit(X_train, y_train)
# Out:
# C:\Users\hp123\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVC()

# %%
y_test_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
SVC=accuracy_score(y_test, y_test_pred)

# %%
print(SVC)
# Out:
# 0.9736842105263158

# %%
metrics.plot_confusion_matrix(classifier, X_test, y_test)

# %% [markdown]
# ## Creating the Data Frame  on ML algorithams and values

# %%
import pandas as pd
data={"ML algorithams":["KNN","Logistic","DT","RF","SVC"],"values":[0.9736842105263158,0.9473684210526315,0.9473684210526315,0.9473684210526315,0.9736842105263158]}
df=pd.DataFrame(data)
df
# Out:
#   ML algorithams    values
# 0            KNN  0.973684
# 1       Logistic  0.947368
# 2             DT  0.947368
# 3             RF  0.947368
# 4            SVC  0.973684

# %%
import seaborn as sns
fig=plt.subplots(figsize=(5,8))

sns.barplot(x='ML algorithams',y="Values",data=df)
# Out:
# <AxesSubplot:xlabel='ML algorithams', ylabel='Values'>

# %% [markdown]
# # conclusion

# %% [markdown]
# In this data i am clearly observing the how to split the data and how learn the data and how to predict the values and the after spliting the data in the data set we have to use the train and  test and the after spilting the data to  do standredization and lable encoding and after the model training phases and in this case  i am used K-nearest,Logistic regession,Dession tree,random forest and support vector classification  and after that comparing the total data using bar plot so this is i am observing total data
